# %% [markdown]
# <a href="https://colab.research.google.com/github/Layana7592/Python/blob/main/data_wise_price_commodity.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
df=pd.read_excel("/content/Date-Wise-Prices-all-Commodity.xlsx")
df
# Out:
#       diffgr:id  msdata:rowOrder           State            District  \
# 0        Table1                0  Andhra Pradesh             Chittor
# 1        Table2                1  Andhra Pradesh             Chittor
# 2        Table3                2  Andhra Pradesh             Chittor
# 3        Table4                3  Andhra Pradesh             Chittor
# 4        Table5                4  Andhra Pradesh             Chittor
# ...         ...              ...             ...                 ...
# 6430  Table6431             6430     West Bengal  Sounth 24 Parganas
# 6431  Table6432             6431     West Bengal  Sounth 24 Parganas
# 6432  Table6433             6432     West Bengal  Sounth 24 Parganas
# 6433  Table6434             6433     West Bengal  Sounth 24 Parganas
# 6434  Table6435             6434     West Bengal  Sounth 24 Parganas
#
#                              Market     Commodity     Variety Grade  \
# 0                          Chittoor  Gur(Jaggery)        NO 1   FAQ
# ...

# %%
df.head()
# Out:
#   diffgr:id  msdata:rowOrder           State District      Market  \
# 0    Table1                0  Andhra Pradesh  Chittor    Chittoor
# 1    Table2                1  Andhra Pradesh  Chittor    Chittoor
# 2    Table3                2  Andhra Pradesh  Chittor    Chittoor
# 3    Table4                3  Andhra Pradesh  Chittor    Punganur
# 4    Table5                4  Andhra Pradesh  Chittor  Vayalapadu
#
#       Commodity Variety Grade Arrival_Date  Min_x0020_Price  Max_x0020_Price  \
# 0  Gur(Jaggery)    NO 1   FAQ   24/02/2023             4000           4100.0
# 1  Gur(Jaggery)    NO 2   FAQ   24/02/2023             3000           3500.0
# 2  Gur(Jaggery)    NO 3   FAQ   24/02/2023             2300           2300.0
# 3        Tomato  Hybrid   FAQ   24/02/2023             1340           2000.0
# 4        Tomato   Local   FAQ   24/02/2023              640           2160.0
#
#    Modal_x0020_Price
# 0             4000.0
# 1             3500.0
# 2             2300.0
# ...

# %%
df.tail()
# Out:
#       diffgr:id  msdata:rowOrder        State            District  \
# 6430  Table6431             6430  West Bengal  Sounth 24 Parganas
# 6431  Table6432             6431  West Bengal  Sounth 24 Parganas
# 6432  Table6433             6432  West Bengal  Sounth 24 Parganas
# 6433  Table6434             6433  West Bengal  Sounth 24 Parganas
# 6434  Table6435             6434  West Bengal  Sounth 24 Parganas
#
#                              Market Commodity     Variety Grade Arrival_Date  \
# 6430  Diamond Harbour(South 24-pgs)     Onion         Red   FAQ   24/02/2023
# 6431  Diamond Harbour(South 24-pgs)    Potato       Jyoti   FAQ   24/02/2023
# 6432  Diamond Harbour(South 24-pgs)      Rice      Common   FAQ   24/02/2023
# 6433  Diamond Harbour(South 24-pgs)      Rice  Super Fine   FAQ   24/02/2023
# 6434  Diamond Harbour(South 24-pgs)    Tomato      Tomato   FAQ   24/02/2023
#
#       Min_x0020_Price  Max_x0020_Price  Modal_x0020_Price
# ...

# %%
df.columns
# Out:
# Index(['diffgr:id', 'msdata:rowOrder', 'State', 'District', 'Market',
#        'Commodity', 'Variety', 'Grade', 'Arrival_Date', 'Min_x0020_Price',
#        'Max_x0020_Price', 'Modal_x0020_Price'],
#       dtype='object')

# %%
df.isna().sum()
# Out:
# diffgr:id            0
# msdata:rowOrder      0
# State                0
# District             0
# Market               0
# Commodity            0
# Variety              0
# Grade                0
# Arrival_Date         0
# Min_x0020_Price      0
# Max_x0020_Price      0
# Modal_x0020_Price    0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6435 entries, 0 to 6434
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   diffgr:id          6435 non-null   object
#  1   msdata:rowOrder    6435 non-null   int64
#  2   State              6435 non-null   object
#  3   District           6435 non-null   object
#  4   Market             6435 non-null   object
#  5   Commodity          6435 non-null   object
#  6   Variety            6435 non-null   object
#  7   Grade              6435 non-null   object
#  8   Arrival_Date       6435 non-null   object
#  9   Min_x0020_Price    6435 non-null   int64
#  10  Max_x0020_Price    6435 non-null   float64
#  11  Modal_x0020_Price  6435 non-null   float64
# dtypes: float64(2), int64(2), object(8)
# memory usage: 603.4+ KB

# %%
df.drop(['diffgr:id','msdata:rowOrder','Arrival_Date'],axis=1,inplace=True)

# %%
from sklearn.preprocessing import LabelEncoder
label=LabelEncoder()
df["State"]=label.fit_transform(df["State"])
df["District"]=label.fit_transform(df["District"])
df["Market"]=label.fit_transform(df["Market"])
df["Commodity"]=label.fit_transform(df["Commodity"])
df["Variety"]=label.fit_transform(df["Variety"])
df["Grade"]=label.fit_transform(df["Grade"])

# %%
sns.boxplot(x='Min_x0020_Price',data=df)
# Out:
# <Axes: xlabel='Min_x0020_Price'>

# %%
sns.boxplot(x='Max_x0020_Price',data=df)
# Out:
# <Axes: xlabel='Max_x0020_Price'>

# %%
import matplotlib.pyplot as plt
def removal_box_plot(df,column,threshold):
  sns.boxplot(df[column])
  plt.title(f'Original boxplot of {column}')
  plt.show()
  removed_outliers=df[df[column]<=threshold]
  sns.boxplot(removed_outliers[column])
  plt.title(f'Without outliers of {column}')
  plt.show()
  return removed_outliers
threshold_value=40
no_outliers=removal_box_plot(df,'Min_x0020_Price',threshold_value)

# %%
import matplotlib.pyplot as plt
def removal_box_plot(df,column,threshold):
  sns.boxplot(df[column])
  plt.title(f'Original boxplot of {column}')
  plt.show()
  removed_outliers=df[df[column]<=threshold]
  sns.boxplot(removed_outliers[column])
  plt.title(f'Without outliers of {column}')
  plt.show()
  return removed_outliers
threshold_value=40
no_outliers=removal_box_plot(df,'Max_x0020_Price',threshold_value)

# %%
x=df.iloc[:,:-1].values
x
# Out:
# array([[   0.,   50.,  124., ...,    0., 4000., 4100.],
#        [   0.,   50.,  124., ...,    0., 3000., 3500.],
#        [   0.,   50.,  124., ...,    0., 2300., 2300.],
#        ...,
#        [  25.,  235.,  155., ...,    0., 2700., 2900.],
#        [  25.,  235.,  155., ...,    0., 4700., 4900.],
#        [  25.,  235.,  155., ...,    0., 1400., 1600.]])

# %%
y=df.iloc[:,-1].values
y
# Out:
# array([4000., 3500., 2300., ..., 2800., 4800., 1500.])

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.30,random_state=42)
x_train
# Out:
# array([[1.00e+01, 4.00e+00, 9.00e+00, ..., 0.00e+00, 4.00e+03, 4.20e+03],
#        [8.00e+00, 2.50e+02, 5.58e+02, ..., 0.00e+00, 5.00e+03, 5.80e+03],
#        [6.00e+00, 1.51e+02, 5.07e+02, ..., 2.00e+00, 4.09e+03, 4.50e+03],
#        ...,
#        [2.30e+01, 1.17e+02, 5.09e+02, ..., 0.00e+00, 3.15e+03, 3.30e+03],
#        [2.30e+01, 1.33e+02, 5.63e+02, ..., 0.00e+00, 1.70e+03, 1.90e+03],
#        [7.00e+00, 1.29e+02, 2.56e+02, ..., 2.00e+00, 4.80e+03, 5.00e+03]])

# %%
y_train
# Out:
# array([4100., 5500., 4200., ..., 3210., 1800., 4900.])

# %%
from sklearn.preprocessing import StandardScaler
scalar=StandardScaler()
scalar.fit(x_train)
x_train=scalar.transform(x_train)
x_test=scalar.transform(x_test)
x_train
# Out:
# array([[-8.86099294e-01, -1.60047662e+00, -1.73447862e+00, ...,
#         -3.65148472e-01, -2.56141893e-03, -1.58695250e-02],
#        [-1.16852738e+00,  1.62267245e+00,  1.52033973e+00, ...,
#         -3.65148472e-01,  4.75436016e-02,  5.23863437e-02],
#        [-1.45095546e+00,  3.25551484e-01,  1.21797956e+00, ...,
#          2.78850200e+00,  1.94803292e-03, -3.07154961e-03],
#        ...,
#        [ 9.49683236e-01, -1.19924404e-01,  1.22983682e+00, ...,
#         -3.65148472e-01, -4.51506864e-02, -5.42634512e-02],
#        [ 9.49683236e-01,  8.97113082e-02,  1.54998289e+00, ...,
#         -3.65148472e-01, -1.17802966e-01, -1.13987336e-01],
#        [-1.30974142e+00,  3.73023803e-02, -2.70106790e-01, ...,
#          2.78850200e+00,  3.75225975e-02,  1.82584094e-02]])

# %%
from sklearn.tree import DecisionTreeRegressor
model=DecisionTreeRegressor()
model.fit(x_train,y_train)
y_pred=model.predict(x_test)
y_pred
# Out:
# array([21000.,   700.,   900., ...,  2665.,  6500.,  1650.])

# %%
from sklearn.metrics import mean_absolute_percentage_error,r2_score
print("MAPE is",mean_absolute_percentage_error(y_test,y_pred))
print("r2 score is",r2_score(y_test,y_pred))
# Out:
# MAPE is 0.027932654245606165
# r2 score is 0.9487843928208977
